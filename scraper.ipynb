# %% [markdown]
# ## Linkedin Scraper
#
# - Referecen: https://github.com/tomquirk/linkedin-api
# - SQLite Viewer: https://inloop.github.io/sqlite-viewer/

# %%
# !pip install linkedin-api

# %%
# !pip install python-dotenv

# %%
from linkedin_api import Linkedin
import os
from dotenv import load_dotenv

load_dotenv()


# Authenticate using any Linkedin account credentials
api = Linkedin(os.getenv("EMAIL"), os.getenv("PWD"))

# GET a profile
profile = api.get_profile('chiphuyen')


# GET a profiles contact info
contact_info = api.get_profile_contact_info('chiphuyen')

# %%
profile

# %%
contact_info

# %%
contact_info = api.get_profile_contact_info('chiphuyen')

# %%
contact_info

# %% [markdown]
# ## Get Posts

# %%
posts = api.get_profile_posts('chiphuyen')

# %%
len(posts)

# %%
posts[0]

# %%
url = posts[0]['socialContent']['shareUrl']
content =  c
like = posts[0]['socialDetail']['likes']['paging']['total']

# %%
content

# %%
url

# %%
import pandas as pd

data = []
for post in posts:
    url = post['socialContent']['shareUrl']
    content = post['commentary']['text']['text']
    like = post['socialDetail']['likes']['paging']['total']
    data.append({'url': url, 'content': content, 'like': like})

df = pd.DataFrame(data)
df

# %%
df.to_csv("huyenchip.csv",index=False)

# %% [markdown]
# ## Save to database

# %% [markdown]
# ## User Class

# %%
import sqlite3
import pandas as pd 

class User:
    def __init__(self, db='linkedin.db'):
        self.db = db
        
    def create_table(self):
        conn = sqlite3.connect(self.db)
        
        # Create a cursor object
        cursor = conn.cursor()

        # Create a table users
        cursor.execute('''CREATE TABLE IF NOT EXISTS users
                         (id INTEGER PRIMARY KEY, name TEXT)''')

        conn.close()
    def insert_user(self, name):
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        result = self.get_user_id(name)
        if result is None:
            cursor.execute("INSERT INTO users (name) VALUES (?)", (name,))
            
            conn.commit()
        else:
            print("user is existed")
        conn.close()

    def query(self):
        # Query the table
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM users")
        rows = cursor.fetchall()
        
        for row in rows:
            print(row)

        conn.close()

        return rows

    def delete_user(self, user_id):
        """
        Deletes a user from the database by their ID.
        
        Args:
            user_id (int): The ID of the user to be deleted.
        """
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        
        # Delete the user from the table
        cursor.execute("DELETE FROM users WHERE id = ?", (user_id,))
        
        # Commit the changes and close the connection
        conn.commit()
        conn.close()

    def get_user_id(self,name):
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM users where name = ?", (name,))
        result = cursor.fetchone()
        conn.close()

        if result is None:
            return None

        return result[0]

# user = User('linkedin.db')
# user.query()
# user.delete_user(2)
# user.query()
# user.insert_user('Hung Le')
# user.get_user_id('Huyen Chip')

# %% [markdown]
# ### Create table posts

# %%
class Post:
    def __init__(self, db='linkedin.db'):
        self.db = db
        self.user = User(db)
        self.table_name = 'posts'
        
    def create_table(self):
        conn = sqlite3.connect(self.db)
        
        # Create a cursor object
        cursor = conn.cursor()

        cursor.execute('''CREATE TABLE IF NOT EXISTS posts
                 (id INTEGER PRIMARY KEY, user_id INTEGER, url TEXT, content TEXT, like INTEGER)''')
        
        conn.commit()

        conn.close()

    def get_urls(self):
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        cursor.execute("SELECT url FROM posts")
        urls = [row[0] for row in cursor.fetchall()]
        conn.close()
        return urls
        
    def insert_post(self, user_name: str, df: pd.DataFrame):
        conn = sqlite3.connect(self.db)
        user_id = self.user.get_user_id(user_name)
        if user_id is not None:
            df['user_id'] = user_id
            inserted_urls = self.get_urls()
            df = df[~df['url'].isin(inserted_urls)]
            df.to_sql(self.table_name, conn, if_exists='append', index=False)

    def query(self, is_show=False):
        # Query the table
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM posts")
        rows = cursor.fetchall()

        if is_show:
            for row in rows:
                print(row)

        conn.close()

        return rows

    def to_df(self, items):
        """ Return the post into dataframe """
        list_data = []
        for item in items:
            list_data.append({"url": item[0], "content": item[1], "like": item[2], 'user_id': item[3]})
        return pd.DataFrame(list_data)
        

    def delete_post(self, post_id):
        """
        Deletes a user from the database by their ID.
        
        Args:
            user_id (int): The ID of the user to be deleted.
        """
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        
        # Delete the user from the table
        cursor.execute("DELETE FROM posts WHERE id = ?", (post_id,))
        
        conn.commit()
        conn.close()

    def delete_all(self):
        """
        Deletes all posts from the database.
        """
        conn = sqlite3.connect(self.db)
        cursor = conn.cursor()
        
        # Delete all posts from the table
        cursor.execute("DELETE FROM posts")
        
        # Commit the changes and close the connection
        conn.commit()
        conn.close()


# post_db = Post('linkedin.db')
# post_db.query()
# post_db.delete_all()

# %% [markdown]
# ## Pipeline
#
# Input: Linkin ID
#
# Output: Save to database

# %%
from linkedin_api import Linkedin
import os
from dotenv import load_dotenv
import pandas as pd


load_dotenv()

INPUT_ID = 'chiphuyen'
# INPUT_ID = 'suvendu-pati-596757114'
POST_COUNT = 20

# Authenticate using any Linkedin account credentials
api = Linkedin(os.getenv("EMAIL"), os.getenv("PWD"))

posts = api.get_profile_posts(INPUT_ID, post_count=POST_COUNT)

data = []
for post in posts:
    url = post['socialContent']['shareUrl']
    content = post['commentary']['text']['text']
    like = post['socialDetail']['likes']['paging']['total']
    data.append({'url': url, 'content': content, 'like': like})

df = pd.DataFrame(data)

user_db = User('linkedin.db')
post_db = Post('linkedin.db')
user_db.create_table()
post_db.create_table()
user_db.insert_user(INPUT_ID)
post_db.insert_post(user_name=INPUT_ID, df=df)
# Out:
# user is existed

# %%
result_df = post_db.to_df(post_db.query())

# %%
result_df
# Out:
#     url  content                                               like  \
# 0     1        1  https://www.linkedin.com/posts/chiphuyen_mleng...
# 1     2        1  https://www.linkedin.com/posts/chiphuyen_llms-...
# 2     3        1  https://www.linkedin.com/posts/chiphuyen_snowf...
# 3     4        1  https://www.linkedin.com/posts/chiphuyen_gpu-d...
# 4     5        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 5     6        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 6     7        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 7     8        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 8     9        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 9    10        1  https://www.linkedin.com/posts/chiphuyen_rag-w...
# 10   11        1  https://www.linkedin.com/posts/chiphuyen_gpus-...
# 11   12        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 12   13        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 13   14        1  https://www.linkedin.com/posts/chiphuyen_gtc20...
# 14   15        1  https://www.linkedin.com/posts/chiphuyen_gtc20...
# 15   16        1  https://www.linkedin.com/posts/chiphuyen_gener...
# 16   17        1  https://www.linkedin.com/posts/chiphuyen_in-co...
# 17   18        1  https://www.linkedin.com/posts/chiphuyen_aieng...
# 18   19        1  https://www.linkedin.com/posts/chiphuyen_mleng...
# 19   20        1  https://www.linkedin.com/posts/chiphuyen_datae...
#
#                                               user_id
# 0   Building a platform for generative AI applicat...
# 1   In many conversations, I noticed several commo...
# 2   As an engineer who've learned so much from wri...
# 3   The rapid adoption of GPUs had made GPU optimi...
# 4   A big issue I see with AI systems is that peop...
# 5   LinkedIn has published one of the best reports...
# 6   I’m making a list of things to consider when u...
# 7   I have this hypothesis that the most popular e...
# 8   I’m excited to share that I’m working on a new...
# 9   Absolutely loved the discussions and the energ...
# 10  Excited to show what our team Voltron Data has...
# 11  I’m often asked what problem I’d solve if I we...
# 12  Had a blast participating in this GTC panel wi...
# 13  It’s been so inspiring to hear about the amazi...
# 14  I'm happy to share that I've joined Voltron Da...
# 15  To understand the open source AI landscape, I ...
# 16  In conversations with companies, I notice a fe...
# 17  A hard part of building AI applications is cho...
# 18  I never dreamed of this happening, but I walke...
# 19  Very proud of our team for their work on ibis ...
